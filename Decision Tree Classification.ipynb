# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# #Desicion Tree classification
#
# -It is also called ID3 algorithm or Iterative dichotomizer
# -It comes from CART (classification and regression trees)
# so we have some componenets in a tree - Root Note : Starting point of a tree - Decision Node : it is the intermediate node of a tree - Branches : These are branches coming from each desicion node and root note -
# Leaf : it is the final desicion for a set of input
# How do we decide how to split ? - Infomation Gain: It is the difference between entropy of system and weighted entropy of that feature.
#                                                                                                                                                     = - Entropy : it is a measure of purity of a feature.( =-summation(plog(p) )) - High entropy : less purity - High information gain : more purity.

# %%
df= pd.read_csv("C:/Users/aksha/Downloads/Dry_Bean_Dataset.csv.zip")
df
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13606  DERMASON
# 13607  DERMASON
# 13608  DERMASON
# 13609  DERMASON
# 13610  DERMASON
#
# [13611 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
#  16  Class            13611 non-null  object
# dtypes: float64(14), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
num= df.columns[:-1]
num
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
#        'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
#        'ShapeFactor3', 'ShapeFactor4'],
#       dtype='object')

# %%
for i in num:
    fig, ax= plt.subplots(1,2,figsize=(10,12))
    ax[0].hist(df[i])
    ax[1].boxplot(df[i])
    plt.suptitle(i)
    plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,14))
sns.heatmap(df[num].corr(), annot=True)
plt.show()

# %%
num
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
#        'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
#        'ShapeFactor3', 'ShapeFactor4'],
#       dtype='object')

# %%
df.drop(['MajorAxisLength','MinorAxisLength', 'Perimeter'], axis=1, inplace=True)

# %%
num= list(num)
num.remove('MajorAxisLength')
num.remove('MinorAxisLength')
num.remove('Perimeter')

# %%
import seaborn as sns
plt.figure(figsize=(10,14))
sns.heatmap(df[num].corr(), annot=True)
plt.show()

# %%
df.drop(['ConvexArea','EquivDiameter', 'ShapeFactor1'], axis=1, inplace=True)
num.remove('ConvexArea')
num.remove('EquivDiameter')
num.remove('ShapeFactor1')

# %%
import seaborn as sns
plt.figure(figsize=(10,14))
sns.heatmap(df[num].corr(), annot=True)
plt.show()

# %%
df.drop('AspectRation', axis=1, inplace=True)
num.remove('AspectRation')

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(df[num].corr(), annot=True)
plt.show()

# %%
df.drop(['roundness','Compactness', 'ShapeFactor2'], axis=1, inplace=True)
num.remove('roundness')
num.remove('Compactness')
num.remove('ShapeFactor2')

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(df[num].corr(), annot=True)
plt.show()

# %%
df.drop('Eccentricity', axis=1, inplace=True)
num.remove('Eccentricity')
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(df[num].corr(), annot=True)
plt.show()

# %%
df['Class'].value_counts()
# Out:
# Class
# DERMASON    3546
# SIRA        2636
# SEKER       2027
# HOROZ       1928
# CALI        1630
# BARBUNYA    1322
# BOMBAY       522
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['Class']=le.fit_transform(df['Class'])
df
# Out:
#         Area    Extent  Solidity  ShapeFactor3  ShapeFactor4  Class
# 0      28395  0.763923  0.988856      0.834222      0.998724      5
# 1      28734  0.783968  0.984986      0.909851      0.998430      5
# 2      29380  0.778113  0.989559      0.825871      0.999066      5
# 3      30008  0.782681  0.976696      0.861794      0.994199      5
# 4      30140  0.773098  0.990893      0.941900      0.999166      5
# ...      ...       ...       ...           ...           ...    ...
# 13606  42097  0.714574  0.990331      0.642988      0.998385      3
# 13607  42101  0.799943  0.990752      0.676099      0.998219      3
# 13608  42139  0.729932  0.989899      0.676884      0.996767      3
# 13609  42147  0.705389  0.987813      0.668237      0.995222      3
# 13610  42159  0.788962  0.989648      0.616221      0.998180      3
#
# [13611 rows x 6 columns]

# %%
# SMOTE - synthetic minority oversampling technique

# %%
X= df.drop('Class', axis=1)
y= df['Class']

# %%
X=X.values
y= y.values

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.2, random_state=100)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree= DecisionTreeClassifier()
dtree.fit(X_train, y_train)
y_train_predicted= dtree.predict(X_train)
y_test_predicted= dtree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report

print("Model Performance")
print("Training accuracy: ", accuracy_score(y_train, y_train_predicted))
# print("Training precsision: ", precision_score(y_train, y_train_predicted))
# print("Training recall: ", recall_score(y_train, y_train_predicted))
print(confusion_matrix(y_train, y_train_predicted))
print(classification_report(y_train, y_train_predicted))
# Out:
# Model Performance
# Training accuracy:  1.0
# [[1073    0    0    0    0    0    0]
#  [   0  413    0    0    0    0    0]
#  [   0    0 1351    0    0    0    0]
#  [   0    0    0 2822    0    0    0]
#  [   0    0    0    0 1546    0    0]
#  [   0    0    0    0    0 1603    0]
#  [   0    0    0    0    0    0 2080]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1073
#            1       1.00      1.00      1.00       413
#            2       1.00      1.00      1.00      1351
#            3       1.00      1.00      1.00      2822
#            4       1.00      1.00      1.00      1546
#            5       1.00      1.00      1.00      1603
#            6       1.00      1.00      1.00      2080
#
#     accuracy                           1.00     10888
#    macro avg       1.00      1.00      1.00     10888
# weighted avg       1.00      1.00      1.00     10888

# %%
print("Model Performance")
print("Testing accuracy: ", accuracy_score(y_test, y_test_predicted))
# print("Training precsision: ", precision_score(y_train, y_train_predicted))
# print("Training recall: ", recall_score(y_train, y_train_predicted))
print()
print(confusion_matrix(y_test, y_test_predicted))
print()

print()

print(classification_report(y_test, y_test_predicted))
# Out:
# Model Performance
# Testing accuracy:  0.8920308483290489
#
# [[213   0  24   0   1   2   9]
#  [  0 107   1   0   0   1   0]
#  [ 18   0 255   0   4   1   1]
#  [  0   0   0 645   6  12  61]
#  [  6   0   3   4 360   0   9]
#  [  2   0   1  11   0 394  16]
#  [  9   0   1  64   6  21 455]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       249
#            1       1.00      0.98      0.99       109
#            2       0.89      0.91      0.90       279
#            3       0.89      0.89      0.89       724
#            4       0.95      0.94      0.95       382
#            5       0.91      0.93      0.92       424
#            6       0.83      0.82      0.82       556
#
#     accuracy                           0.89      2723
#    macro avg       0.91      0.90      0.91      2723
# weighted avg       0.89      0.89      0.89      2723

# %%
from sklearn.model_selection import GridSearchCV
dtree= DecisionTreeClassifier()
param_grid={
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_search= GridSearchCV(dtree, param_grid, cv=5)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 10, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %%
grid_search.best_params
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 grid_search.best_params
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params'

# %%
#GridSearchCV in Decision Tree Classifier
grid_search.best_score_
# Out:
# 0.8986033129558415

# %%
dtree= DecisionTreeClassifier(criterion='entropy',max_depth= 10, min_samples_leaf= 4,min_samples_split= 5)
dtree.fit(X_train, y_train)
y_train_predicted= dtree.predict(X_train)
y_test_predicted= dtree.predict(X_test)

# %%
print("Model Performance")
print("Tranining accuracy:", accuracy_score(y_train, y_train_predicted))
# print("Tranining precision:", precision_score(y_train, y_train_predicted))
# print("Tranining recall:", recall_score(y_train, y_train_predicted))
print()
print( confusion_matrix(y_train, y_train_predicted))
print()

print()
print( classification_report(y_train, y_train_predicted))
# Out:
# Model Performance
# Tranining accuracy: 0.9372703894195444
#
# [[ 975    1   70    2    4    3   18]
#  [   1  412    0    0    0    0    0]
#  [  45    1 1278    0   16    3    8]
#  [   0    0    0 2672    1   25  124]
#  [   4    0   15    8 1494    0   25]
#  [   4    0    0   29    1 1534   35]
#  [   6    0    8  193   19   14 1840]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93      1073
#            1       1.00      1.00      1.00       413
#            2       0.93      0.95      0.94      1351
#            3       0.92      0.95      0.93      2822
#            4       0.97      0.97      0.97      1546
#            5       0.97      0.96      0.96      1603
#            6       0.90      0.88      0.89      2080
#
#     accuracy                           0.94     10888
#    macro avg       0.95      0.94      0.95     10888
# weighted avg       0.94      0.94      0.94     10888

# %%
print("Model Performance")
print("Testing accuracy:", accuracy_score(y_test, y_test_predicted))
# print("Testing precision:", precision_score(y_test, y_test_predicted))
# print("Testing recall:", recall_score(y_test, y_test_predicted))
print()
print( confusion_matrix(y_test, y_test_predicted))
print()

print()
print(classification_report(y_test, y_test_predicted))
# Out:
# Model Performance
# Testing accuracy: 0.9114946749908189
#
# [[211   0  26   0   2   5   5]
#  [  1 108   0   0   0   0   0]
#  [ 10   2 259   0   7   1   0]
#  [  0   0   0 682   3   5  34]
#  [  1   0   6   5 362   0   8]
#  [  2   0   1   9   0 397  15]
#  [  5   0   3  67  14   4 463]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88       249
#            1       0.98      0.99      0.99       109
#            2       0.88      0.93      0.90       279
#            3       0.89      0.94      0.92       724
#            4       0.93      0.95      0.94       382
#            5       0.96      0.94      0.95       424
#            6       0.88      0.83      0.86       556
#
#     accuracy                           0.91      2723
#    macro avg       0.92      0.92      0.92      2723
# weighted avg       0.91      0.91      0.91      2723

# %% [markdown]
# # Random forest

# %% [markdown]
# -Ensemble learning - a model which is made by combining multiple models.
# -random forest is a combination of multiple desicion trees over multiple samples.
# -in random forest we split training data into multiple samples.
# -and we also select few features in each sample to introduce randomness.
# -we train desicion tree for each samples.
# -finally combine the result of all trees that is the output of random forest.
# -it takes rows and columns randomly.

# %%
df.info
# Out:
# <bound method DataFrame.info of         Area    Extent  Solidity  ShapeFactor3  ShapeFactor4  Class
# 0      28395  0.763923  0.988856      0.834222      0.998724      5
# 1      28734  0.783968  0.984986      0.909851      0.998430      5
# 2      29380  0.778113  0.989559      0.825871      0.999066      5
# 3      30008  0.782681  0.976696      0.861794      0.994199      5
# 4      30140  0.773098  0.990893      0.941900      0.999166      5
# ...      ...       ...       ...           ...           ...    ...
# 13606  42097  0.714574  0.990331      0.642988      0.998385      3
# 13607  42101  0.799943  0.990752      0.676099      0.998219      3
# 13608  42139  0.729932  0.989899      0.676884      0.996767      3
# 13609  42147  0.705389  0.987813      0.668237      0.995222      3
# 13610  42159  0.788962  0.989648      0.616221      0.998180      3
#
# [13611 rows x 6 columns]>

# %%
df.columns
# Out:
# Index(['Area', 'Extent', 'Solidity', 'ShapeFactor3', 'ShapeFactor4', 'Class'], dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf= RandomForestClassifier(max_depth=10)

# %%
rf.fit(X_train, y_train)
y_train_predicted= rf.predict(X_train)
y_test_predicted= rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report

# %%
print("Model Performance")
print("Tranining accuracy:", accuracy_score(y_train, y_train_predicted))
# print("Tranining precision:", precision_score(y_train, y_train_predicted))
# print("Tranining recall:", recall_score(y_train, y_train_predicted))
print()
print( confusion_matrix(y_train, y_train_predicted))
print()

print()
print( classification_report(y_train, y_train_predicted))
# Out:
# Model Performance
# Tranining accuracy: 0.9494856722997795
#
# [[ 985    0   58    0    2    0   28]
#  [   0  413    0    0    0    0    0]
#  [  30    0 1306    0    4    2    9]
#  [   0    0    0 2693    0   14  115]
#  [   0    0   17    7 1496    0   26]
#  [   1    0    0   21    0 1545   36]
#  [   0    0    5  166    2    7 1900]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94      1073
#            1       1.00      1.00      1.00       413
#            2       0.94      0.97      0.95      1351
#            3       0.93      0.95      0.94      2822
#            4       0.99      0.97      0.98      1546
#            5       0.99      0.96      0.97      1603
#            6       0.90      0.91      0.91      2080
#
#     accuracy                           0.95     10888
#    macro avg       0.96      0.95      0.96     10888
# weighted avg       0.95      0.95      0.95     10888

# %%
print("Model Performance")
print("Testing accuracy:", accuracy_score(y_test, y_test_predicted))
# print("Testing precision:", precision_score(y_test, y_test_predicted))
# print("Testing recall:", recall_score(y_test, y_test_predicted))
print()
print( confusion_matrix(y_test, y_test_predicted))
print()

print()
print(classification_report(y_test, y_test_predicted))
# Out:
# Model Performance
# Testing accuracy: 0.9192067572530297
#
# [[218   0  20   0   1   1   9]
#  [  0 109   0   0   0   0   0]
#  [ 10   0 263   0   5   1   0]
#  [  0   0   0 676   2   6  40]
#  [  1   0   7   3 363   0   8]
#  [  2   0   0  11   0 398  13]
#  [  0   0   2  64   8   6 476]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       249
#            1       1.00      1.00      1.00       109
#            2       0.90      0.94      0.92       279
#            3       0.90      0.93      0.91       724
#            4       0.96      0.95      0.95       382
#            5       0.97      0.94      0.95       424
#            6       0.87      0.86      0.86       556
#
#     accuracy                           0.92      2723
#    macro avg       0.93      0.93      0.93      2723
# weighted avg       0.92      0.92      0.92      2723

# %% [markdown]
# # support vector machine

# %% [markdown]
# y= wtX + b
# if the line is above the hyperplane then wtX + B= +1
# if the line is below the hyperplane then wtX + B = -1
# when the gap between wt is increase then the gap is decreasing or vice versa.
# The goal is to maximize the gap between the hyperplane and dataset.

# %%
from sklearn.svm import SVC
svc= SVC(C= 1.0, kernel= 'linear')
svc.fit(X_train, y_train)
y_train_predicted= svc.predict(X_train)
y_test_predicted= svc.predict(X_test)

# %%
print("Model Performance")
print("Tranining accuracy:", accuracy_score(y_train, y_train_predicted))
# print("Tranining precision:", precision_score(y_train, y_train_predicted))
# print("Tranining recall:", recall_score(y_train, y_train_predicted))
print()
print( confusion_matrix(y_train, y_train_predicted))
print()

print()
print( classification_report(y_train, y_train_predicted))
# Out:
# Model Performance
# Tranining accuracy: 0.6272042615723733
#
# [[ 145    0  677    0  226    0   25]
#  [   0  412    1    0    0    0    0]
#  [  96    0 1160    0   92    0    3]
#  [   0    0    0 2413    0  342   67]
#  [  99    0   60   34  995   54  304]
#  [   0    0    0  576   80  454  493]
#  [   1    0    0  118  390  321 1250]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.14      0.21      1073
#            1       1.00      1.00      1.00       413
#            2       0.61      0.86      0.71      1351
#            3       0.77      0.86      0.81      2822
#            4       0.56      0.64      0.60      1546
#            5       0.39      0.28      0.33      1603
#            6       0.58      0.60      0.59      2080
#
#     accuracy                           0.63     10888
#    macro avg       0.62      0.62      0.61     10888
# weighted avg       0.60      0.63      0.60     10888

# %%
print("Model Performance")
print("Testing accuracy:", accuracy_score(y_test, y_test_predicted))
# print("Testing precision:", precision_score(y_test, y_test_predicted))
# print("Testing recall:", recall_score(y_test, y_test_predicted))
print()
print( confusion_matrix(y_test, y_test_predicted))
print()

print()
print(classification_report(y_test, y_test_predicted))
# Out:
# Model Performance
# Testing accuracy: 0.6312890194638267
#
# [[ 33   0 155   0  59   0   2]
#  [  0 108   1   0   0   0   0]
#  [ 31   0 236   0  12   0   0]
#  [  0   0   0 618   0  87  19]
#  [ 30   0  17   3 250   9  73]
#  [  0   0   0 141  17 139 127]
#  [  0   0   0  33 106  82 335]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.35      0.13      0.19       249
#            1       1.00      0.99      1.00       109
#            2       0.58      0.85      0.69       279
#            3       0.78      0.85      0.81       724
#            4       0.56      0.65      0.61       382
#            5       0.44      0.33      0.38       424
#            6       0.60      0.60      0.60       556
#
#     accuracy                           0.63      2723
#    macro avg       0.62      0.63      0.61      2723
# weighted avg       0.61      0.63      0.61      2723

# %%
#knn classifier 
from sklearn.neighbors import KNeighborsClassifier
y_train
# Out:
# array([5, 3, 0, ..., 6, 4, 4])

# %%
knn_model= KNeighborsClassifier(7)
knn_model.fit(X_train, y_train)
ytrain_knn_predicted= knn_model.predict(X_train)
ytrain_knn_predicted
# Out:
# array([3, 3, 2, ..., 5, 4, 6])

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(X_test, y_test)
ytest_knn_predicted = knn_model.predict(X_test)
ytest_knn_predicted
# Out:
# array([0, 3, 6, ..., 4, 5, 4])

# %%
print("Model Performance")
print("Tranining accuracy:", accuracy_score(y_train, ytrain_knn_predicted))
# print("Tranining precision:", precision_score(y_train, ytrain_knn_predicted))
# print("Tranining recall:", recall_score(y_train, ytrain_knn_predicted))
print(  )

print( confusion_matrix(y_train, ytrain_knn_predicted))
print()
print(classification_report(y_train, ytrain_knn_predicted))
# Out:
# Model Performance
# Tranining accuracy: 0.6960874357090375
#
# [[ 464    0  398    1  175    2   33]
#  [   0  412    1    0    0    0    0]
#  [ 214    0 1055    0   79    0    3]
#  [   0    0    0 2500    1  222   99]
#  [ 104    0   62   49  995   59  277]
#  [   4    0    1  434   66  730  368]
#  [   6    0    0  170  239  242 1423]]
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.43      0.50      1073
#            1       1.00      1.00      1.00       413
#            2       0.70      0.78      0.74      1351
#            3       0.79      0.89      0.84      2822
#            4       0.64      0.64      0.64      1546
#            5       0.58      0.46      0.51      1603
#            6       0.65      0.68      0.66      2080
#
#     accuracy                           0.70     10888
#    macro avg       0.71      0.70      0.70     10888
# weighted avg       0.69      0.70      0.69     10888

# %%
print("Model Performance")
print("Testing Accuracy: ", accuracy_score(y_test, ytest_knn_predicted))
print()
# print("Testing Precision: ", precision_score(y_test,ytest_knn_predicted))
# print("Testing Recall: ", recall_score(y_test, ytest_knn_predicted))
print()
print(confusion_matrix(y_test,ytest_knn_predicted))
print()
print(classification_report(y_test,ytest_knn_predicted))
# Out:
# Model Performance
# Testing Accuracy:  0.7227322805728975
#
#
# [[129   0  79   0  37   0   4]
#  [  1 108   0   0   0   0   0]
#  [ 48   0 218   0  12   0   1]
#  [  0   0   0 653   0  57  14]
#  [ 31   0  13   4 253  17  64]
#  [  0   0   0 109  18 226  71]
#  [  1   0   0  46  62  66 381]]
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.52      0.56       249
#            1       1.00      0.99      1.00       109
#            2       0.70      0.78      0.74       279
#            3       0.80      0.90      0.85       724
#            4       0.66      0.66      0.66       382
#            5       0.62      0.53      0.57       424
#            6       0.71      0.69      0.70       556
#
#     accuracy                           0.72      2723
#    macro avg       0.73      0.72      0.73      2723
# weighted avg       0.72      0.72      0.72      2723

# %%
from sklearn.model_selection import GridSearchCV
dt= KNeighborsClassifier()
param_grid={

        'n_neighbors': [3, 5, 7, 9],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan', 'minkowski']


}

# %%
grid_search= GridSearchCV(dt, param_grid, cv=5)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']})

# %%
grid_search.best_params_
# Out:
# {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'uniform'}

# %%
grid_search.best_score_
# Out:
# 0.6024975609015364

# %%
knn_model = KNeighborsClassifier(metric='manhattan', n_neighbors= 9, weights='uniform')
knn_model.fit(X_test, y_test)
ytest_knn_predicted = knn_model.predict(X_test)
ytest_knn_predicted
# Out:
# array([0, 3, 6, ..., 4, 3, 4])

# %%
print("Model Performance")
print("Tranining accuracy:", accuracy_score(y_train, ytrain_knn_predicted))
# print("Tranining precision:", precision_score(y_train, ytrain_knn_predicted))
# print("Tranining recall:", recall_score(y_train, ytrain_knn_predicted))
print(  )

print( confusion_matrix(y_train, ytrain_knn_predicted))
print()
print(classification_report(y_train, ytrain_knn_predicted))
# Out:
# Model Performance
# Tranining accuracy: 0.6960874357090375
#
# [[ 464    0  398    1  175    2   33]
#  [   0  412    1    0    0    0    0]
#  [ 214    0 1055    0   79    0    3]
#  [   0    0    0 2500    1  222   99]
#  [ 104    0   62   49  995   59  277]
#  [   4    0    1  434   66  730  368]
#  [   6    0    0  170  239  242 1423]]
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.43      0.50      1073
#            1       1.00      1.00      1.00       413
#            2       0.70      0.78      0.74      1351
#            3       0.79      0.89      0.84      2822
#            4       0.64      0.64      0.64      1546
#            5       0.58      0.46      0.51      1603
#            6       0.65      0.68      0.66      2080
#
#     accuracy                           0.70     10888
#    macro avg       0.71      0.70      0.70     10888
# weighted avg       0.69      0.70      0.69     10888

# %%
print("Model Performance")
print("Testing Accuracy: ", accuracy_score(y_test, ytest_knn_predicted))
print()
# print("Testing Precision: ", precision_score(y_test,ytest_knn_predicted))
# print("Testing Recall: ", recall_score(y_test, ytest_knn_predicted))
print()
print(confusion_matrix(y_test,ytest_knn_predicted))
print()
print(classification_report(y_test,ytest_knn_predicted))
# Out:
# Model Performance
# Testing Accuracy:  0.6918839515240544
#
#
# [[105   0  92   0  46   0   6]
#  [  0 108   1   0   0   0   0]
#  [ 45   0 219   0  14   0   1]
#  [  0   0   0 637   0  68  19]
#  [ 27   0  13   8 242  11  81]
#  [  0   0   0 118  20 189  97]
#  [  1   0   0  38  64  69 384]]
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.42      0.49       249
#            1       1.00      0.99      1.00       109
#            2       0.67      0.78      0.73       279
#            3       0.80      0.88      0.84       724
#            4       0.63      0.63      0.63       382
#            5       0.56      0.45      0.50       424
#            6       0.65      0.69      0.67       556
#
#     accuracy                           0.69      2723
#    macro avg       0.70      0.69      0.69      2723
# weighted avg       0.68      0.69      0.68      2723

# %%
! pip install gradio

# %%
import gradio as gr
def prediction(Area, Extent, Solidity, ShapeFactor3, ShapeFactor4):
    input_data= np.array([[Area, Extent, Solidity, ShapeFactor3, ShapeFactor4]])
    input_data.reshape(1,-1)
    prediction= rf.predict(input_data)
    return le.inverse_transform(prediction)[0]

# %%
df['Class']

# %%
df.iloc[0,:].values

# %%
inputs= [
    gr.Number(label="Enter Area"),
    gr.Number(label="Enter Extent"),
    gr.Number(label="Enter Solidity"),
    gr.Number(label="Enter ShapeFactor3"),
    gr.Number(label="Enter ShapeFactor4")
]

# %%
output= gr.Textbox(label= 'Prediction')

# %%
gr.Interface(fn= prediction, inputs= inputs, outputs= output, title="Beans classification",
             description= "Enter the input data",
            ).launch(share= True)
